# %%
from pygbif import species

# %%
species.name_suggest(q='Witheringia solanacea')
# Out:
# [{'key': 8625966,
#   'nameKey': 11856744,
#   'kingdom': 'Plantae',
#   'phylum': 'Tracheophyta',
#   'order': 'Solanales',
#   'family': 'Solanaceae',
#   'genus': 'Witheringia',
#   'species': 'Witheringia solanacea',
#   'kingdomKey': 6,
#   'phylumKey': 7707728,
#   'classKey': 220,
#   'orderKey': 1176,
#   'familyKey': 7717,
#   'genusKey': 5341755,
#   'speciesKey': 8625966,
#   'parent': 'Witheringia',
#   'parentKey': 5341755,
#   'nubKey': 8625966,
#   'scientificName': "Witheringia solanacea L'Hér.",
#   'canonicalName': 'Witheringia solanacea',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'higherClassificationMap': {'6': 'Plantae',
#    '7707728': 'Tracheophyta',
#    '220': 'Magnoliopsida',
#    '1176': 'Solanales',
#    '7717': 'Solanaceae',
#    '5341755': 'Witheringia'},
#   'synonym': False,
#   'class': 'Magnoliopsida'},
#  {'key': 7299733,
#   'nameKey': 31985694,
#   'kingdom': 'Plantae',
#   'phylum': 'Tracheophyta',
#   'order': 'Solanales',
# ...
